# %% [markdown]
# Objectif : Chiffrement et déchiffrement RSA d’un message.

# %%
from cryptography.hazmat.primitives.asymmetric import padding
from cryptography.hazmat.primitives import hashes, serialization
#chiffrement asymetrique RSA
#charger les cles 
with open("private_key.pem", "rb") as key_file:
    private_key = serialization.load_pem_private_key(
        key_file.read(),
        password=None,
    )
with open("public_key.pem", "rb") as key_file:
    public_key = serialization.load_pem_public_key(
        key_file.read(),
    )
message = b"Devoir 3A LIA"
#chiffrer le message avec la cle publique
ciphertext = public_key.encrypt(
    message,
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
)
print("Ciphertext:", ciphertext)
print("le message a ete chiffre avec succes")
# Out:
# Ciphertext: b"\x02|0\x9f\xda\xc8\x01\x99$<\x87\x13\x04o$\xebB\x90\xef\xa8Jv$\x8b\xbd~\x10\x87\xfb\x00=u\x9e\x90\x8aH\xddm\x03y\x9fS\xb9a\xd16\xefQoW\xdf\x9cy\x8av\x13\x8a/B\xed\xa8\x17B\xa2\xf1&77\xd8\xf4\xa1\x1a\xee\x00kI\xda\x12\x0f4\x19G\xdf\xe1\x1b\xc9KkS\xe5\xa7#\xdb\x8dH_\x99\xe2U\xa4\xc0f\x80X\x9e|d\xbc\x01O\xa0\x99I;U.\xc8K\x96\xf0\x86E\xf0C\xc7\x1c\xfbM\xbb\xfc\xf3\xf0GS\x9dX'\x9a\x0f%\x16\xc3\x19\x04\x19\x1e_\xcb\xb1)O\xbe\x93\x87\xeb.\xa5\xc1\x98\xbc\x87c,\x90H\xca\xd5\xadVsW\x8f\xb1Q\xe9>F;\x10!b\x15\xee\xaa\xffLF\x88T\xa4h\x00\xd3\x90\x89T`}\x88\x1a\xa7\xdf-\x91\x8c)\x81n\xa1\xdc]\x17\xdf\xe3A`\x94\x1d\x90\xc4\xaa\xd7q\xb4X\x01*\xa7\x1ed/d\xbfj\x9e\x10\xfez \x1b\xb0)\xc9\xf5b]u\xef|\xa4 \x16\xdf\xb1\xb3\x93"
# le message a ete chiffre avec succes

# %%
#dechiffrer le message avec la cle privee
plaintext = private_key.decrypt(
    ciphertext,
    padding.OAEP(
        mgf=padding.MGF1(algorithm=hashes.SHA256()),
        algorithm=hashes.SHA256(),
        label=None
    )
)
print("Plaintext:", plaintext)
print("le message a ete dechiffre avec succes")
# Out:
# Plaintext: b'Devoir 3A LIA'
# le message a ete dechiffre avec succes
